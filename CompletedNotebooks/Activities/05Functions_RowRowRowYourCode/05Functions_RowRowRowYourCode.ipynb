# %% [markdown]
# # Row, Row, Row Your Code
# ## Goals
#
# This activity will practice function decomposition: identifying potential functions, creating functions, removing repetitive code, making code more efficient, and debugging code with functions. You will work in teams of two (three if necessary). Be sure to make a new project for this activity, as you will be making multiple files.
#
# ### Key principles:
# When there are patterns of repetitive code, design a function to perform that repetitive code, replacing the code by a call to the function.
# Things that vary between similar-but-not-identical code can become inputs to a function.
# Don’t refer to global variables inside a function, ever.
#
# ### Overview
#
# With this activity you will use everything you've learned so far to turn a long and complex-seeming program into a short, elegant, efficient program. The original program is more than 300 lines of code; your final program will be fewer than 60 lines of actual code, plus a few blank lines.
#
# Follow the instructions and do each step as you are given it. There is a reason we've chosen to have you perform the steps in the order given. Trust us!
#
# For each step of this lab, you should:
#
# - Read the step.
# - If the step asks you to discuss, reflect, or write, do so in the markdown reflection cells given.
# - If you become stuck on any step for longer than 2 minutes, ask for help!
# - Once you've completed the step, make sure all team members understand the solution and could reproduce it.

# %%
# The program draws 5 flowers with green sepals (first), pink petals (second), purple centres (third) 
# and finally a yellow stamp, using 4 turtles

import turtle
import math

win = turtle.Screen()
win.bgcolor("light sky blue")

sepalTurtle = turtle.Turtle()
sepalTurtle.speed(0)
sepalTurtle.color("dark green", "spring green")
sepalTurtle.hideturtle()

petalTurtle = turtle.Turtle()
petalTurtle.speed(0)
petalTurtle.color('dark red', 'light coral')
petalTurtle.hideturtle()

centerTurtle = turtle.Turtle()
centerTurtle.speed(0)
centerTurtle.color('purple4')
centerTurtle.hideturtle()

stampTurtle = turtle.Turtle()
stampTurtle.color("gold")
stampTurtle.speed(0)
stampTurtle.shape("turtle")
stampTurtle.hideturtle()

sepalTurtle.up()
sepalTurtle.goto(0, 0)
sepalTurtle.down()
sepalTurtle.begin_fill()
sepalTurtle.circle(50)
sepalTurtle.end_fill()
sepalTurtle.left(72)
sepalTurtle.begin_fill()
sepalTurtle.circle(50)
sepalTurtle.end_fill()
sepalTurtle.left(72)
sepalTurtle.begin_fill()
sepalTurtle.circle(50)
sepalTurtle.end_fill()
sepalTurtle.left(72)
sepalTurtle.begin_fill()
sepalTurtle.circle(50)
sepalTurtle.end_fill()
sepalTurtle.left(72)
sepalTurtle.begin_fill()
sepalTurtle.circle(50)
sepalTurtle.end_fill()
sepalTurtle.left(72)

petalTurtle.up()
petalTurtle.goto(0, 0)
petalTurtle.down()
petalTurtle.begin_fill()
petalTurtle.circle(25)
petalTurtle.end_fill()
petalTurtle.left(72)
petalTurtle.begin_fill()
petalTurtle.circle(25)
petalTurtle.end_fill()
petalTurtle.left(72)
petalTurtle.begin_fill()
petalTurtle.circle(25)
petalTurtle.end_fill()
petalTurtle.left(72)
petalTurtle.begin_fill()
petalTurtle.circle(25)
petalTurtle.end_fill()
petalTurtle.left(72)
petalTurtle.begin_fill()
petalTurtle.circle(25)
petalTurtle.end_fill()
petalTurtle.left(72)

centerTurtle.up()
centerTurtle.goto(0, -15)
centerTurtle.down()
centerTurtle.begin_fill()
centerTurtle.circle(15)
centerTurtle.end_fill()

stampTurtle.up()
stampTurtle.goto(-2,0)
stampTurtle.down()
stampTurtle.stamp()

sepalTurtle.up()
sepalTurtle.goto(0, 220)
sepalTurtle.down()
sepalTurtle.begin_fill()
sepalTurtle.circle(50)
sepalTurtle.end_fill()
sepalTurtle.left(72)
sepalTurtle.begin_fill()
sepalTurtle.circle(50)
sepalTurtle.end_fill()
sepalTurtle.left(72)
sepalTurtle.begin_fill()
sepalTurtle.circle(50)
sepalTurtle.end_fill()
sepalTurtle.left(72)
sepalTurtle.begin_fill()
sepalTurtle.circle(50)
sepalTurtle.end_fill()
sepalTurtle.left(72)
sepalTurtle.begin_fill()
sepalTurtle.circle(50)
sepalTurtle.end_fill()
sepalTurtle.left(72)

petalTurtle.up()
petalTurtle.goto(0, 220)
petalTurtle.down()
petalTurtle.begin_fill()
petalTurtle.circle(25)
petalTurtle.end_fill()
petalTurtle.left(72)
petalTurtle.begin_fill()
petalTurtle.circle(25)
petalTurtle.end_fill()
petalTurtle.left(72)
petalTurtle.begin_fill()
petalTurtle.circle(25)
petalTurtle.end_fill()
petalTurtle.left(72)
petalTurtle.begin_fill()
petalTurtle.circle(25)
petalTurtle.end_fill()
petalTurtle.left(72)
petalTurtle.begin_fill()
petalTurtle.circle(25)
petalTurtle.end_fill()
petalTurtle.left(72)

centerTurtle.up()
centerTurtle.goto(0, 205)
centerTurtle.down()
centerTurtle.begin_fill()
centerTurtle.circle(15)
centerTurtle.end_fill()

stampTurtle.up()
stampTurtle.goto(-2,220)
stampTurtle.down()
stampTurtle.stamp()

sepalTurtle.up()
sepalTurtle.goto(220, 0)
sepalTurtle.down()
sepalTurtle.begin_fill()
sepalTurtle.circle(50)
sepalTurtle.end_fill()
sepalTurtle.left(72)
sepalTurtle.begin_fill()
sepalTurtle.circle(50)
sepalTurtle.end_fill()
sepalTurtle.left(72)
sepalTurtle.begin_fill()
sepalTurtle.circle(50)
sepalTurtle.end_fill()
sepalTurtle.left(72)
sepalTurtle.begin_fill()
sepalTurtle.circle(50)
sepalTurtle.end_fill()
sepalTurtle.left(72)
sepalTurtle.begin_fill()
sepalTurtle.circle(50)
sepalTurtle.end_fill()
sepalTurtle.left(72)

petalTurtle.up()
petalTurtle.goto(220, 0)
petalTurtle.down()
petalTurtle.begin_fill()
petalTurtle.circle(25)
petalTurtle.end_fill()
petalTurtle.left(72)
petalTurtle.begin_fill()
petalTurtle.circle(25)
petalTurtle.end_fill()
petalTurtle.left(72)
petalTurtle.begin_fill()
petalTurtle.circle(25)
petalTurtle.end_fill()
petalTurtle.left(72)
petalTurtle.begin_fill()
petalTurtle.circle(25)
petalTurtle.end_fill()
petalTurtle.left(72)
petalTurtle.begin_fill()
petalTurtle.circle(25)
petalTurtle.end_fill()
petalTurtle.left(72)

centerTurtle.up()
centerTurtle.goto(220, -15)
centerTurtle.down()
centerTurtle.begin_fill()
centerTurtle.circle(15)
centerTurtle.end_fill()

stampTurtle.up()
stampTurtle.goto(218,0)
stampTurtle.down()
stampTurtle.stamp()

sepalTurtle.up()
sepalTurtle.goto(0, -220)
sepalTurtle.down()
sepalTurtle.begin_fill()
sepalTurtle.circle(50)
sepalTurtle.end_fill()
sepalTurtle.left(72)
sepalTurtle.begin_fill()
sepalTurtle.circle(50)
sepalTurtle.end_fill()
sepalTurtle.left(72)
sepalTurtle.begin_fill()
sepalTurtle.circle(50)
sepalTurtle.end_fill()
sepalTurtle.left(72)
sepalTurtle.begin_fill()
sepalTurtle.circle(50)
sepalTurtle.end_fill()
sepalTurtle.left(72)
sepalTurtle.begin_fill()
sepalTurtle.circle(50)
sepalTurtle.end_fill()
sepalTurtle.left(72)

petalTurtle.up()
petalTurtle.goto(0, -220)
petalTurtle.down()
petalTurtle.begin_fill()
petalTurtle.circle(25)
petalTurtle.end_fill()
petalTurtle.left(72)
petalTurtle.begin_fill()
petalTurtle.circle(25)
petalTurtle.end_fill()
petalTurtle.left(72)
petalTurtle.begin_fill()
petalTurtle.circle(25)
petalTurtle.end_fill()
petalTurtle.left(72)
petalTurtle.begin_fill()
petalTurtle.circle(25)
petalTurtle.end_fill()
petalTurtle.left(72)
petalTurtle.begin_fill()
petalTurtle.circle(25)
petalTurtle.end_fill()
petalTurtle.left(72)

centerTurtle.up()
centerTurtle.goto(0, -235)
centerTurtle.down()
centerTurtle.begin_fill()
centerTurtle.circle(15)
centerTurtle.end_fill()

stampTurtle.up()
stampTurtle.goto(-2,-220)
stampTurtle.down()
stampTurtle.stamp()

sepalTurtle.up()
sepalTurtle.goto(-220, 0)
sepalTurtle.down()
sepalTurtle.begin_fill()
sepalTurtle.circle(50)
sepalTurtle.end_fill()
sepalTurtle.left(72)
sepalTurtle.begin_fill()
sepalTurtle.circle(50)
sepalTurtle.end_fill()
sepalTurtle.left(72)
sepalTurtle.begin_fill()
sepalTurtle.circle(50)
sepalTurtle.end_fill()
sepalTurtle.left(72)
sepalTurtle.begin_fill()
sepalTurtle.circle(50)
sepalTurtle.end_fill()
sepalTurtle.left(72)
sepalTurtle.begin_fill()
sepalTurtle.circle(50)
sepalTurtle.end_fill()
sepalTurtle.left(72)

petalTurtle.up()
petalTurtle.goto(-220, 0)
petalTurtle.down()
petalTurtle.begin_fill()
petalTurtle.circle(25)
petalTurtle.end_fill()
petalTurtle.left(72)
petalTurtle.begin_fill()
petalTurtle.circle(25)
petalTurtle.end_fill()
petalTurtle.left(72)
petalTurtle.begin_fill()
petalTurtle.circle(25)
petalTurtle.end_fill()
petalTurtle.left(72)
petalTurtle.begin_fill()
petalTurtle.circle(25)
petalTurtle.end_fill()
petalTurtle.left(72)
petalTurtle.begin_fill()
petalTurtle.circle(25)
petalTurtle.end_fill()
petalTurtle.left(72)

centerTurtle.up()
centerTurtle.goto(-220, -15)
centerTurtle.down()
centerTurtle.begin_fill()
centerTurtle.circle(15)
centerTurtle.end_fill()

stampTurtle.up()
stampTurtle.goto(-222,0)
stampTurtle.down()
stampTurtle.stamp()

win.exitonclick()

# %% [markdown]
# ## Step 1: What does the program do?
#
# Observe the code below. This script has no functions, no loops, nor does it have any comments. Work through the steps below.
#
# 1. Read through the script without running it. Can you figure out anything about what the script is doing? Discuss it as a team.
# 2. Run the program. What happened? Try running it several times and watch closely what it does.
# 3. Suppose you wanted to add a descriptive comment to the start of the program, that describes the purpose of the program. In this section, write out the contents of such a comment. Don't modify the code yet! Your descriptive comment should explain these, among other things:
#
#     a. What shapes are being drawn? How are the shapes layered? What colors are involved?
#
#     b. In what order are the shapes drawn?
#
#     c.How many turtles are in the code?
#
# ## Put your written notes here
#
# The program draws 5 flowers with green sepals (first), pink petals (second), purple centres (third) and finally a yellow stamp, using 4 turtles
#
#
#
# ## Step 2: Using loops to reduce repetitive code
#
# In this section we will use a method of simplifying code that you learned earlier: using a loop to avoid a sequence of repetitive code. **Note:** For now we will only work with one sequence of repetitive code, even though that sequence occurs over and over, as well. Perform each step below, in order.
#
# 1. Make a copy of the code from the cell above to the cell below. This way, the original code will remain unchanged, and if necessary you can delete the new work and start over with the original again. We always want to keep a copy of every working version of the program, in case we modify it and can't get the new one working.
# 2. Look at lines 28 through 50. What sequence of lines is being repeated over and over? How many times does the sequence repeat? Discuss how you might use a loop to simplify this code. Record your ideas in this markdown cell under the section called "Code Notes". **IMPORTANT:** In a code cell, htting escape key followed by the L key (lowercase not caps) will reveal line numbers.
# 3. In the following cod cell, implement your ideas for condensing lines 28 through 50. Do not change any other part of the script (for now). Run and test the new program to ensure that it still works exactly as before. Remember that you can still run the original script above for comparison.
# 4. Find all the other places in the script with code similar to lines 28 through 50. For each, replace the original code by the new loop you’ve designed. **Note: the code segments are not identical: you will need to determine the differences and adjust the new loop accordingly.**   There should be a total of ten segments replaced. Make sure to **test your code after you introduce each of the ten loops** to make sure it works correctly.
#
# ## Code notes
#
# Lines 31-34 are being repeated 5 times. So we could put these statements in a for loop to simplify the program.

# %%
import turtle
import math

win = turtle.Screen()
win.bgcolor("light sky blue")

sepalTurtle = turtle.Turtle()
sepalTurtle.speed(0)
sepalTurtle.color("dark green", "spring green")
sepalTurtle.hideturtle()

petalTurtle = turtle.Turtle()
petalTurtle.speed(0)
petalTurtle.color('dark red', 'light coral')
petalTurtle.hideturtle()

centerTurtle = turtle.Turtle()
centerTurtle.speed(0)
centerTurtle.color('purple4')
centerTurtle.hideturtle()

stampTurtle = turtle.Turtle()
stampTurtle.color("gold")
stampTurtle.speed(0)
stampTurtle.shape("turtle")
stampTurtle.hideturtle()

sepalTurtle.up()
sepalTurtle.goto(0, 0)
sepalTurtle.down()
for f1 in range(5):
    sepalTurtle.begin_fill()
    sepalTurtle.circle(50)
    sepalTurtle.end_fill()
    sepalTurtle.left(72)

petalTurtle.up()
petalTurtle.goto(0, 0)
petalTurtle.down()
for f2 in range (5):
    petalTurtle.begin_fill()
    petalTurtle.circle(25)
    petalTurtle.end_fill()
    petalTurtle.left(72)

centerTurtle.up()
centerTurtle.goto(0, -15)
centerTurtle.down()
centerTurtle.begin_fill()
centerTurtle.circle(15)
centerTurtle.end_fill()

stampTurtle.up()
stampTurtle.goto(-2,0)
stampTurtle.down()
stampTurtle.stamp()

sepalTurtle.up()
sepalTurtle.goto(0, 220)
sepalTurtle.down()
for f3 in range(5):    
    sepalTurtle.begin_fill()
    sepalTurtle.circle(50)
    sepalTurtle.end_fill()
    sepalTurtle.left(72)

petalTurtle.up()
petalTurtle.goto(0, 220)
petalTurtle.down()
for f4 in range(5):
    petalTurtle.begin_fill()
    petalTurtle.circle(25)
    petalTurtle.end_fill()
    petalTurtle.left(72)

centerTurtle.up()
centerTurtle.goto(0, 205)
centerTurtle.down()
centerTurtle.begin_fill()
centerTurtle.circle(15)
centerTurtle.end_fill()

stampTurtle.up()
stampTurtle.goto(-2,220)
stampTurtle.down()
stampTurtle.stamp()

sepalTurtle.up()
sepalTurtle.goto(220, 0)
sepalTurtle.down()
for f5 in range(5):
    sepalTurtle.begin_fill()
    sepalTurtle.circle(50)
    sepalTurtle.end_fill()
    sepalTurtle.left(72)

petalTurtle.up()
petalTurtle.goto(220, 0)
petalTurtle.down()
for f6 in range(5):
    petalTurtle.begin_fill()
    petalTurtle.circle(25)
    petalTurtle.end_fill()
    petalTurtle.left(72)

centerTurtle.up()
centerTurtle.goto(220, -15)
centerTurtle.down()
centerTurtle.begin_fill()
centerTurtle.circle(15)
centerTurtle.end_fill()

stampTurtle.up()
stampTurtle.goto(218,0)
stampTurtle.down()
stampTurtle.stamp()

sepalTurtle.up()
sepalTurtle.goto(0, -220)
sepalTurtle.down()
for f7 in range(5):
    sepalTurtle.begin_fill()
    sepalTurtle.circle(50)
    sepalTurtle.end_fill()
    sepalTurtle.left(72)


petalTurtle.up()
petalTurtle.goto(0, -220)
petalTurtle.down()
for f8 in range(5):
    petalTurtle.begin_fill()
    petalTurtle.circle(25)
    petalTurtle.end_fill()
    petalTurtle.left(72)

centerTurtle.up()
centerTurtle.goto(0, -235)
centerTurtle.down()
centerTurtle.begin_fill()
centerTurtle.circle(15)
centerTurtle.end_fill()

stampTurtle.up()
stampTurtle.goto(-2,-220)
stampTurtle.down()
stampTurtle.stamp()

sepalTurtle.up()
sepalTurtle.goto(-220, 0)
sepalTurtle.down()
for f9 in range(5):
    sepalTurtle.begin_fill()
    sepalTurtle.circle(50)
    sepalTurtle.end_fill()
    sepalTurtle.left(72)

petalTurtle.up()
petalTurtle.goto(-220, 0)
petalTurtle.down()
for f10 in range(5):    
    petalTurtle.begin_fill()
    petalTurtle.circle(25)
    petalTurtle.end_fill()
    petalTurtle.left(72)

centerTurtle.up()
centerTurtle.goto(-220, -15)
centerTurtle.down()
centerTurtle.begin_fill()
centerTurtle.circle(15)
centerTurtle.end_fill()

stampTurtle.up()
stampTurtle.goto(-222,0)
stampTurtle.down()
stampTurtle.stamp()

win.exitonclick()

# %% [markdown]
# ## Step 3: Abstracting details to create a function
#
# In the last step, you figured out how to reduce a set of lines using a loop, and then you replaced 10 similar sections with a similar loop. Repeating a pattern 10 times is a clear sign that a function is needed. The next steps will walk you through an analysis of how the function should work.
#
# 1. As before, save a copy of the code in the last cell into the code cell below, and make all new changes to the new script in that cell below.
# 2. Each of the sequences you found in the last step is preceded by lines that move the relevant turtle to a specific location. Taken all together, these lines draw five circles evenly spaced around a center point, with a specified size. The colors of the circles are taken from the turtle’s colors. Thus we will call our new function drawFiveCircles.
# 3. Look at the first two occurrences of the circle-drawing sequences. Discuss as a team what parts of each section stay the same, and what parts differ. In the section below in this cell, record the parts that differ, and have instructor or preceptor check you on this.
# *Commentary: When defining a function, the parts that differ become input parameters: we use abstraction to generalize the different parts by making them something that is passed in as a value during a call to the function.*
# 4. You should have found four significant differences: the turtle doing the drawing, the radius of the circles being drawn, and the center (x, y) location that the turtle moves to before drawing. Make these four values be input parameters to drawFiveCircles.
# 5. Add the definition of drawFiveCircles at the top of the file, just below the import statements. Give it four inputs: turt, radius, centerX, and centerY.
# 6. Copy the first occurrence of the movement code and the loop you created, and paste them as the body of your new function. Be sure they are indented properly under the function header line (the line that starts with def).
# 7. Inside the body of the function, replace every reference to the drawing turtle by turt, replace the circle’s radius by the input variable radius, and replace the x and y location for the goto with centerX and centerY.
# 8. Add a summary, descriptive comment to describe your function. This is done by putting a triple-quoted string that starts, indented as a part of the function, right after the header line, and before any actual lines of the function body. The descriptive comment should explain what the inputs to the function are, and what the function does.
# 9. Next you need to test and debug your new function.
#     a. Find the code that you copied into the function, and comment out those lines.
#
#     b. Add a line that calls your new function, like this: drawFiveCircles(sepalTurtle, 50, 0, 0)
#
#     c. Test your function by running the program, and keep debugging until the program works exactly as it did before.
#
#     d. When the program runs correctly, then you can delete the lines you commented out.
#
# 10. Repeat this process for the lines that draw the first flower’s petals, replacing the lines with a call like this: drawFiveCircles(petalTurtle, 25, 0, 0)
# 11. Do the same for each of the  4 other flowers that are drawn, testing each one before you move on to the next. In the end your program should be at least half as long as the original.
#
#
# ## What parts differ? (from number 3 above)
# The turtle which will draw the part, radius of the curcle (for stamp this is 0), the x coordinate of the turtle's starting position and lastly, the y coordinate of the turtle's starting position

# %%
import turtle
import math

def drawFiveCircles(turt, radius, centerX, centerY):
    """This function takes 4 input variables (the turtle-turt, radius of circle-radius, 
       and coordinate values-centerX & centerY) and makes 5 circles (filled) of the 
       given radius using the given turtles, starting at given coordinates, rotating 
       left by 72 degrees each time.
    """
    turt.up()
    turt.goto(centerX, centerY)
    turt.down()
    for f in range(5):
        turt.begin_fill()
        turt.circle(radius)
        turt.end_fill()
        turt.left(72)

win = turtle.Screen()
win.bgcolor("light sky blue")

sepalTurtle = turtle.Turtle()
sepalTurtle.speed(0)
sepalTurtle.color("dark green", "spring green")
sepalTurtle.hideturtle()

petalTurtle = turtle.Turtle()
petalTurtle.speed(0)
petalTurtle.color('dark red', 'light coral')
petalTurtle.hideturtle()

centerTurtle = turtle.Turtle()
centerTurtle.speed(0)
centerTurtle.color('purple4')
centerTurtle.hideturtle()

stampTurtle = turtle.Turtle()
stampTurtle.color("gold")
stampTurtle.speed(0)
stampTurtle.shape("turtle")
stampTurtle.hideturtle()

drawFiveCircles(sepalTurtle, 50, 0, 0)
drawFiveCircles(petalTurtle, 25, 0, 0)    

centerTurtle.up()
centerTurtle.goto(0, -15)
centerTurtle.down()
centerTurtle.begin_fill()
centerTurtle.circle(15)
centerTurtle.end_fill()

stampTurtle.up()
stampTurtle.goto(-2,0)
stampTurtle.down()
stampTurtle.stamp()

drawFiveCircles(sepalTurtle, 50, 0, 220)
drawFiveCircles(petalTurtle, 25, 0, 220)    

centerTurtle.up()
centerTurtle.goto(0, 205)
centerTurtle.down()
centerTurtle.begin_fill()
centerTurtle.circle(15)
centerTurtle.end_fill()

stampTurtle.up()
stampTurtle.goto(-2,220)
stampTurtle.down()
stampTurtle.stamp()

drawFiveCircles(sepalTurtle, 50, 220, 0)
drawFiveCircles(petalTurtle, 25, 220, 0)  

centerTurtle.up()
centerTurtle.goto(220, -15)
centerTurtle.down()
centerTurtle.begin_fill()
centerTurtle.circle(15)
centerTurtle.end_fill()

stampTurtle.up()
stampTurtle.goto(218,0)
stampTurtle.down()
stampTurtle.stamp()

drawFiveCircles(sepalTurtle, 50, 0, -220)
drawFiveCircles(petalTurtle, 25, 0, -220) 

centerTurtle.up()
centerTurtle.goto(0, -235)
centerTurtle.down()
centerTurtle.begin_fill()
centerTurtle.circle(15)
centerTurtle.end_fill()

stampTurtle.up()
stampTurtle.goto(-2,-220)
stampTurtle.down()
stampTurtle.stamp()

drawFiveCircles(sepalTurtle, 50, -220, 0)
drawFiveCircles(petalTurtle, 25, -220, 0) 

centerTurtle.up()
centerTurtle.goto(-220, -15)
centerTurtle.down()
centerTurtle.begin_fill()
centerTurtle.circle(15)
centerTurtle.end_fill()

stampTurtle.up()
stampTurtle.goto(-222,0)
stampTurtle.down()
stampTurtle.stamp()

win.exitonclick()

# %% [markdown]
# ## Step 4: Making a function for the flower center
#
# For the next step we will create a function that contains the instructions to draw the center circle of each flower.
#
# 1. As before, save a copy of of your previous work in the cell below. Do all this work in the new cell.
# 2. Look at the script code for the first two flowers. What code sequence draws the circle at the center of the flower? How is this code similar, and what differences are there? What is the relationship between the center position used for the sepals and petals, and the turtle’s location for drawing the center circle. Answer these questions right here in this cell.
# 3. At the top of the file, near the definition of drawFiveCircles, add a new function drawCenterCircle that takes three input parameters: a turtle and the center x and center y locations of the overall flower. Be sure to include a triple-quoted descriptive comment just inside the function body.
# *Commentary: why include the turtle when it is always the same? See the last principle at the top of the file. Whenever possible, avoid using global variables inside your functions! Pass the turtle into the function as a parameter.*
# 4. Copy the lines from the first center-drawing sequence, and paste them as the body of your new function. Change the code to use the input turtle and input center x and center y variables you defined as inputs to your function.
# 5. Test your function by replacing the code you copied with a call to your new function. The first flower’s call should look like: drawCenterCircle(centerTurtle, 0, 0)
# 6. Repeat the process of replacing code for the other four flowers, testing each one as you go.
#
# ### Question answers can go here:
#
# The sequence of codes for drawing a circle at the centre differs only slightly from the code for drawing the sepals and petals. Instead of drawing 5 circles and rotating 72 degrees left after each, this sequence just draws one circle, not rotating after that. Secondly, for each circle, the turtle goes to the same x-coordinate but -15 y-coordinate as compared to the sepal and petal turtles.
#
# Although it is always the same, we do include the turtle since its a global object. Global variables should never be used inside functions; so we pass it as a parameter.

# %%
import turtle
import math

def drawFiveCircles(turt, radius, centerX, centerY):
    """This function takes 4 input variables (the turtle-turt, radius of circle-radius, 
       and coordinate values-centerX & centerY) and makes 5 circles (filled) of the 
       given radius using the given turtles, starting at given coordinates, rotating 
       left by 72 degrees each time.
    """
    turt.up()
    turt.goto(centerX, centerY)
    turt.down()
    for f in range(5):
        turt.begin_fill()
        turt.circle(radius)
        turt.end_fill()
        turt.left(72)

def drawCenterCircle(turt, centerX, centerY):
    """This function accepts a turtle and the coordinates to go to. It then draws a
       circle of radius 15 units at that x position and -15 y position
    """
    turt.up()
    turt.goto(centerX, centerY-15)
    turt.down()
    turt.begin_fill()
    turt.circle(15)
    turt.end_fill()
        
win = turtle.Screen()
win.bgcolor("light sky blue")

sepalTurtle = turtle.Turtle()
sepalTurtle.speed(0)
sepalTurtle.color("dark green", "spring green")
sepalTurtle.hideturtle()

petalTurtle = turtle.Turtle()
petalTurtle.speed(0)
petalTurtle.color('dark red', 'light coral')
petalTurtle.hideturtle()

centerTurtle = turtle.Turtle()
centerTurtle.speed(0)
centerTurtle.color('purple4')
centerTurtle.hideturtle()

stampTurtle = turtle.Turtle()
stampTurtle.color("gold")
stampTurtle.speed(0)
stampTurtle.shape("turtle")
stampTurtle.hideturtle()

drawFiveCircles(sepalTurtle, 50, 0, 0)
drawFiveCircles(petalTurtle, 25, 0, 0)    
drawCenterCircle(centerTurtle, 0, 0)

stampTurtle.up()
stampTurtle.goto(-2,0)
stampTurtle.down()
stampTurtle.stamp()

drawFiveCircles(sepalTurtle, 50, 0, 220)
drawFiveCircles(petalTurtle, 25, 0, 220)    
drawCenterCircle(centerTurtle, 0, 220)

stampTurtle.up()
stampTurtle.goto(-2,220)
stampTurtle.down()
stampTurtle.stamp()

drawFiveCircles(sepalTurtle, 50, 220, 0)
drawFiveCircles(petalTurtle, 25, 220, 0)  
drawCenterCircle(centerTurtle, 220, 0)

stampTurtle.up()
stampTurtle.goto(218,0)
stampTurtle.down()
stampTurtle.stamp()

drawFiveCircles(sepalTurtle, 50, 0, -220)
drawFiveCircles(petalTurtle, 25, 0, -220) 
drawCenterCircle(centerTurtle, 0, -220)

stampTurtle.up()
stampTurtle.goto(-2,-220)
stampTurtle.down()
stampTurtle.stamp()

drawFiveCircles(sepalTurtle, 50, -220, 0)
drawFiveCircles(petalTurtle, 25, -220, 0) 
drawCenterCircle(centerTurtle, -220, 0)

stampTurtle.up()
stampTurtle.goto(-222,0)
stampTurtle.down()
stampTurtle.stamp()

win.exitonclick()

# %% [markdown]
# ## Step 5: Making a function to stamp a honeybee
#
# The stampTurtle in the code remains unchanged. It stamps a yellow turtle shape (let’s pretend it is a honeybee) in the middle of each flower. Now let’s create a function that will take in a turtle, and the center x and y positions, and will stamp a honeybee in the flower’s middle.
# 1. As before, save a copy of your previous work below. Do all this work in the new file.
# 2. Look at the script code for the first two flowers. What code sequence stamps the turtle shape at the center of the flower? How is this code similar, and what differences are there? What is the relationship between the center position used for the sepals and petals, and the turtle’s location for stamping. Answer these questions in the space below.
# 3. At the top of the file, near the definition of drawFiveCircles, add a new function drawBee that takes three inputs: a turtle and the center x and center y locations of the overall flower. Be sure to include a triple-quoted descriptive comment just inside the function body.
# 4. Copy the lines from the first turtle-stamping sequence, and paste them as the body of your new function. Change the code to use the input turtle and input center x and center y variables you defined as inputs to your function.
# 5. Test your function by replacing the code you copied with a call to your new function. The first flower’s call should look like: drawBee(stampTurtle, 0, 0)
# 6. Repeat the process of replacing code for the other four flowers, testing each one as you go.
#
# ### Question answers can go here:
#
# The sequence of codes for stamping a turtle at the centre differs from the code for drawing the stepals and petals in that, instead of drawing 5 circles and rotating 72 degrees left after each, this sequence just stamps a turtle in the centre, not drawing circles. Secondly, for each circle, the turtle goes to the same y-coordinate but -2 x-coordinate as compared to the sepal and petal turtles.

# %%
import turtle
import math

def drawFiveCircles(turt, radius, centerX, centerY):
    """This function takes 4 input variables (the turtle-turt, radius of circle-radius, 
       and coordinate values-centerX & centerY) and makes 5 circles (filled) of the 
       given radius using the given turtles, starting at given coordinates, rotating 
       left by 72 degrees each time.
    """
    turt.up()
    turt.goto(centerX, centerY)
    turt.down()
    for f in range(5):
        turt.begin_fill()
        turt.circle(radius)
        turt.end_fill()
        turt.left(72)

def drawCenterCircle(turt, centerX, centerY):
    """This function accepts a turtle and the coordinates to go to. It then draws a
       circle of radius 15 units at that x position and -15 y position
    """
    turt.up()
    turt.goto(centerX, centerY-15)
    turt.down()
    turt.begin_fill()
    turt.circle(15)
    turt.end_fill()

def drawBee(turt, centerX, centerY):
    """This function accepts a turtle and the coordinates to go to. It then stamps a
       turtle at -2 x position and the exact y position
    """
    turt.up()
    turt.goto(centerX-2,centerY)
    turt.down()
    turt.stamp()
        
win = turtle.Screen()
win.bgcolor("light sky blue")

sepalTurtle = turtle.Turtle()
sepalTurtle.speed(0)
sepalTurtle.color("dark green", "spring green")
sepalTurtle.hideturtle()

petalTurtle = turtle.Turtle()
petalTurtle.speed(0)
petalTurtle.color('dark red', 'light coral')
petalTurtle.hideturtle()

centerTurtle = turtle.Turtle()
centerTurtle.speed(0)
centerTurtle.color('purple4')
centerTurtle.hideturtle()

stampTurtle = turtle.Turtle()
stampTurtle.color("gold")
stampTurtle.speed(0)
stampTurtle.shape("turtle")
stampTurtle.hideturtle()

drawFiveCircles(sepalTurtle, 50, 0, 0)
drawFiveCircles(petalTurtle, 25, 0, 0)    
drawCenterCircle(centerTurtle, 0, 0)
drawBee(stampTurtle, 0, 0)

drawFiveCircles(sepalTurtle, 50, 0, 220)
drawFiveCircles(petalTurtle, 25, 0, 220)    
drawCenterCircle(centerTurtle, 0, 220)
drawBee(stampTurtle, 0, 220)

drawFiveCircles(sepalTurtle, 50, 220, 0)
drawFiveCircles(petalTurtle, 25, 220, 0)  
drawCenterCircle(centerTurtle, 220, 0)
drawBee(stampTurtle, 220, 0)

drawFiveCircles(sepalTurtle, 50, 0, -220)
drawFiveCircles(petalTurtle, 25, 0, -220) 
drawCenterCircle(centerTurtle, 0, -220)
drawBee(stampTurtle, 0, -220)

drawFiveCircles(sepalTurtle, 50, -220, 0)
drawFiveCircles(petalTurtle, 25, -220, 0) 
drawCenterCircle(centerTurtle, -220, 0)
drawBee(stampTurtle, -220, 0)

win.exitonclick()

# %% [markdown]
# ## Step 6: Drawing a whole flower at once
#
# Now you should be able to see the larger pattern very clearly: each flower should now be created by a sequence of four calls to functions you’ve created. If you look at the calls for different flowers, they differ only in what the center x and y location is. Now we’ll make a function to draw a whole flower at once.
# 1. As before, save a copy of your previous work below. Do all this work in the new file.
# 2. Define a function at the top of the file called drawFlower. While it seems awkward, give it six input parameters: four different turtles, a center x value, and a center y value. This avoids referring to global variables inside your function. Be sure to include a triple-quoted descriptive comment just inside the function body.
# 3. Copy the lines for drawing the first flower (the four calls to your functions), and generalize them to use the input variables.
# 4. Test your function by replacing the code you copied with a call to your new function.
# 5. Repeat the process of replacing code for the other four flowers, testing each one as you go.

# %%
import turtle
import math

def drawFlower(turt1, turt2, turt3, turt4, centerX, centerY):
    """This function draws one whole flower by calling upon the other functions."""
    drawFiveCircles(turt1, 50, centerX, centerY)
    drawFiveCircles(turt2, 25, centerX, centerY)    
    drawCenterCircle(turt3, centerX, centerY)
    drawBee(turt4, centerX, centerY)

def drawFiveCircles(turt, radius, centerX, centerY):
    """This function takes 4 input variables (the turtle-turt, radius of circle-radius, 
       and coordinate values-centerX & centerY) and makes 5 circles (filled) of the 
       given radius using the given turtles, starting at given coordinates, rotating 
       left by 72 degrees each time.
    """
    turt.up()
    turt.goto(centerX, centerY)
    turt.down()
    for f in range(5):
        turt.begin_fill()
        turt.circle(radius)
        turt.end_fill()
        turt.left(72)

def drawCenterCircle(turt, centerX, centerY):
    """This function accepts a turtle and the coordinates to go to. It then draws a
       circle of radius 15 units at that x position and -15 y position
    """
    turt.up()
    turt.goto(centerX, centerY-15)
    turt.down()
    turt.begin_fill()
    turt.circle(15)
    turt.end_fill()

def drawBee(turt, centerX, centerY):
    """This function accepts a turtle and the coordinates to go to. It then stamps a
       turtle at -2 x position and the exact y position
    """
    turt.up()
    turt.goto(centerX-2,centerY)
    turt.down()
    turt.stamp()
        
win = turtle.Screen()
win.bgcolor("light sky blue")

sepalTurtle = turtle.Turtle()
sepalTurtle.speed(0)
sepalTurtle.color("dark green", "spring green")
sepalTurtle.hideturtle()

petalTurtle = turtle.Turtle()
petalTurtle.speed(0)
petalTurtle.color('dark red', 'light coral')
petalTurtle.hideturtle()

centerTurtle = turtle.Turtle()
centerTurtle.speed(0)
centerTurtle.color('purple4')
centerTurtle.hideturtle()

stampTurtle = turtle.Turtle()
stampTurtle.color("gold")
stampTurtle.speed(0)
stampTurtle.shape("turtle")
stampTurtle.hideturtle()

drawFlower(sepalTurtle, petalTurtle, centerTurtle, stampTurtle, 0, 0)
drawFlower(sepalTurtle, petalTurtle, centerTurtle, stampTurtle, 0, 220)
drawFlower(sepalTurtle, petalTurtle, centerTurtle, stampTurtle, 220, 0)
drawFlower(sepalTurtle, petalTurtle, centerTurtle, stampTurtle, 0, -220)
drawFlower(sepalTurtle, petalTurtle, centerTurtle, stampTurtle, -220, 0)

win.exitonclick()

# %% [markdown]
# ## Optional Step 7: Making a main function
#
# The last step might be to encapsulate everything that was still being done in the script by a main program, so that there are no global variables left. This will be an acid test of whether your other functions successfully avoid referring to global variables!
# 1. As before, save a copy of your work below. Do all this work in the new cell.
# 2. Define a function at the top of the file called drawAll. It should take in no inputs. Take all of the script lines that remain (creating the turtles, and then drawing the flowers, ending with the exitonclick call) and put them into this function. Be sure to include a triple-quoted descriptive comment just inside the function body.
# 3. Replace the script part of your file by a single call to drawAll().
# 4. Test it to be sure everything still works.

# %%
import turtle
import math

def drawAll():
    """This function acts as the main function encapsulate everything that was previously being done in the script,
       so that there are no global variables left
    """
    win = turtle.Screen()
    win.bgcolor("light sky blue")

    sepalTurtle = turtle.Turtle()
    sepalTurtle.speed(0)
    sepalTurtle.color("dark green", "spring green")
    sepalTurtle.hideturtle()

    petalTurtle = turtle.Turtle()
    petalTurtle.speed(0)
    petalTurtle.color('dark red', 'light coral')
    petalTurtle.hideturtle()

    centerTurtle = turtle.Turtle()
    centerTurtle.speed(0)
    centerTurtle.color('purple4')
    centerTurtle.hideturtle()

    stampTurtle = turtle.Turtle()
    stampTurtle.color("gold")
    stampTurtle.speed(0)
    stampTurtle.shape("turtle")
    stampTurtle.hideturtle()

    drawFlower(sepalTurtle, petalTurtle, centerTurtle, stampTurtle, 0, 0)
    drawFlower(sepalTurtle, petalTurtle, centerTurtle, stampTurtle, 0, 220)
    drawFlower(sepalTurtle, petalTurtle, centerTurtle, stampTurtle, 220, 0)
    drawFlower(sepalTurtle, petalTurtle, centerTurtle, stampTurtle, 0, -220)
    drawFlower(sepalTurtle, petalTurtle, centerTurtle, stampTurtle, -220, 0)

    win.exitonclick()

def drawFlower(turt1, turt2, turt3, turt4, centerX, centerY):
    """This function draws one whole flower by calling upon the other functions"""
    drawFiveCircles(turt1, 50, centerX, centerY)
    drawFiveCircles(turt2, 25, centerX, centerY)    
    drawCenterCircle(turt3, centerX, centerY)
    drawBee(turt4, centerX, centerY)

def drawFiveCircles(turt, radius, centerX, centerY):
    """This function takes 4 input variables (the turtle-turt, radius of circle-radius, 
       and coordinate values-centerX & centerY) and makes 5 circles (filled) of the 
       given radius using the given turtles, starting at given coordinates, rotating 
       left by 72 degrees each time
    """
    turt.up()
    turt.goto(centerX, centerY)
    turt.down()
    for f in range(5):
        turt.begin_fill()
        turt.circle(radius)
        turt.end_fill()
        turt.left(72)

def drawCenterCircle(turt, centerX, centerY):
    """This function accepts a turtle and the coordinates to go to. It then draws a
       circle of radius 15 units at that x position and -15 y position
    """
    turt.up()
    turt.goto(centerX, centerY-15)
    turt.down()
    turt.begin_fill()
    turt.circle(15)
    turt.end_fill()

def drawBee(turt, centerX, centerY):
    """This function accepts a turtle and the coordinates to go to. It then stamps a
       turtle at -2 x position and the exact y position
    """
    turt.up()
    turt.goto(centerX-2,centerY)
    turt.down()
    turt.stamp()
        
drawAll()
